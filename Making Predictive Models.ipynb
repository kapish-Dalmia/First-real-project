# %%
# DATA EXPLORATION

# %%
# importing libraries

import pandas as pd #to get the data for data exploration
import seaborn as sns #to check the realationship between the data for exploratory data analysis
import numpy as np # in case if needed

# %%
data = pd.read_csv(r"C:\Users\Rohit\Desktop\A.I. PROJECT\a.i. practice\house_data.csv") # going to the data and reading the file

# if the file name has backward slashes(\) then we put r in front .
# but if the file has forward backslashes(/) we dont use r in front.

# %%
data.head() # this functions shows the first five rows of the data.
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.tail() # this funtion shows the last five rows of the data.
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
data.columns # shows the name of the columns in the data.
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data.shape # gives the number of rows and thne the no. of columns in the data (rows , columns)
# Out:
# (21613, 21)

# %%
data.describe() # shows the mean value  , the standard deviation , minium , maxiumum values ,etc.
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
# DATA VISUALIZATION

# %%
sns.relplot(x='price' , y='id', data=data)

# %%
sns.relplot(x='price', y='date', data=data)

# %%
sns.relplot(x="price" , y="bedrooms" , data=data )

# %%
sns.relplot(x="price" , y="bathrooms" , data=data)

# %%
sns.relplot(x="price" , y="sqft_living" , data=data)

# %%
sns.relplot(x='price', y='sqft_lot', data=data)

# %%
sns.relplot(x="price" , y="floors" , data=data)

# %%
sns.relplot(x="price" , y="waterfront" , data=data)

# %%
sns.relplot(x="price" , y="view" , data=data)

# %%
sns.relplot(x="price" , y="condition" , data=data)

# %%
sns.relplot(x="price" , y="grade" , data=data)

# %%
sns.relplot(x="price" , y="sqft_above" , data=data)

# %%
sns.relplot(x="price" , y="sqft_basement" , data=data)

# %%
sns.relplot(x="price" , y="yr_built" , data=data)

# %%
sns.relplot(x="price" , y="yr_renovated" , data=data)

# %%
sns.relplot(x="price" , y="zipcode" , data=data)

# %%
sns.relplot(x="price" , y="lat" , data=data)

# %%
sns.relplot(x="price" , y="long" , data=data)

# %%
sns.relplot(x="price" , y="sqft_living15" , data=data)

# %%
sns.relplot(x="price" , y="sqft_lot15"  , data=data)

# %%
sns.relplot(x="price" , y="sqft_living" , hue="waterfront" , data=data)

# %%
#modeeling

# %%
#installing libraries
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
train = data.drop(['price' , 'id' , 'date'] , axis=1)
test = data['price']

# %%
X_train , X_test , y_train , y_test = train_test_split(train, test , test_size=0.3 , random_state=3)

# %%
regr = LinearRegression()

# %%
regr.fit(X_train , y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
T

# %%
predict
# Out:
# array([ 538654.96257609, 1301551.06621108,  769032.57407036, ...,
#         127450.29524505,  332100.290482  ,  368857.57302697])

# %%
regr.score(X_test , y_test)
# Out:
# 0.7019457714827467

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
train = data.drop(['price' , 'date' , 'id'] , axis=1)
test = data['price']

# %%
X_train , X_test , y_train , y_test = train_test_split(train, test , test_size=0.2 , random_state=3)

# %%
regr = LinearRegression()

# %%
regr.fit(X_train , y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
predict = regr.predict(X_test)

# %%
predict
# Out:
# array([ 542741.09678162, 1304996.2121262 ,  768516.6077207 , ...,
#        1064498.54952518, 1278912.26058345,  200396.17688934])

# %%
regr.score(X_test , y_test)
# Out:
# 0.7077188146880624
