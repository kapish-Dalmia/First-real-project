# %%
import pandas as pd
import seaborn as sns

# %%
new = pd.read_csv('new.csv')
sns.heatmap(new.corr())

# %%
import pandas as pd
import seaborn as sns

# %%
new = pd.read_csv('new.csv')
sns.heatmap(new.corr())

# %%
import pandas as pd
import seaborn as sns

# %%
new = pd.read_csv('new2.csv')
sns.heatmap(new.corr())

# %%
import pandas as pd
import seaborn as sns
