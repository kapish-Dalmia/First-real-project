# 18997 -57.8600  74.5740  259.3160  h
# 18998 -21.4436  28.9553  210.8496  h
# 18999   6.3984   7.6304  289.2860  h
# 19000  32.3612  44.7320  102.9950  h
# 19001  21.2864   9.3725  281.8795  h
# 19002  17.1609  80.4307  223.9730  h
# 19003  15.6128  88.3032  269.0718  h
# 19004   6.8613  35.3166  152.0720  h
# 19005 -12.2698  47.3704  246.0565  h
# 19006   8.4777  28.0100  336.9910  h
# 19007 -31.0503  28.1458  319.3730  h
# 19008 -12.9245  46.2680  187.0970  h
# 19009   8.4813  69.1730  120.6680  h
# 19010 -30.0054  15.8075  311.5680  h
# 19011  11.1098  11.3663  100.0566  h
# 19012 -62.6192  82.1691  283.4731  h
# 19013  -3.6545  78.4099  224.8299  h
# 19014   2.8766   2.4229  106.8258  h
# 19015  -2.9632  86.7975  247.4560  h
# 19016  -9.4662  30.2987  256.5166  h
# 19017 -63.8389  84.6874  408.3166  h
# 19018  31.4755  52.7310  272.3174  h
#
# [19019 rows x 11 columns]

# %%
cols = ["fLength", "fWidth" , "fSize", "fConc", "fConc1", "fAsym", "fM3Long", "fM3Trans", "fAlpha", "fDist", "class"]
df = pd.read_csv("magic04.data", names = cols)
df.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g

# %%
#df["class"].unique()
df["class"] = (df["class"] =="g").astype(int)

# %%
df.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist  class
# 0  40.0920   81.8828      1
# 1   6.3609  205.2610      1
# 2  76.9600  256.7880      1
# 3  10.4490  116.7370      1
# 4   4.6480  356.4620      1

# %%
df.tail()
# Out:
#         fLength   fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 19015   21.3846  10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19016   28.9452   6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19017   75.4455  47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19018  120.5135  76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19019  187.1814  53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fM3Trans   fAlpha     fDist  class
# 19015    2.8766   2.4229  106.8258      0
# 19016   -2.9632  86.7975  247.4560      0
# 19017   -9.4662  30.2987  256.5166      0
# 19018  -63.8389  84.6874  408.3166      0
# 19019   31.4755  52.7310  272.3174      0

# %%
for label in cols[:-1]:
    plt.hist(df[df["class"]==1][label] , color = "blue" , label = "gamma" , alpha = 0.7 , density = True)
    plt.hist(df[df["class"]==0][label] , color = "red" , label = "hadron" , alpha = 0.7 , density = True)
    plt.title(label)
    plt.ylabel('Probability')
    plt.xlabel(label)
    plt.legend()
    plt.show()

# %%
train , valid, test = np.split(df.sample(frac = 1) , [int(0.6*len(df)) , int(0.8*len(df))])

# %%
def scale_dataset(dataframe, oversample = False):
    x = dataframe[dataframe.columns[:-1]].values
    y = dataframe[dataframe.columns[-1]].values
    
    scaler = StandardScaler()
    x = scaler.fit_transform(x)
    
    if oversample:
        ros = RandomOverSampler()
        x, y = ros.fit_resample(x, y)
    
    data = np.hstack((x, np.reshape(y , (-1 , 1))))
    return data , x,  y

# %%
# train

print(len(train[train["class"] == 1]))
print(len(train[train["class"] == 0]))
# Out:
# 7432
# 3980

# %%
'''
print(len(train[train["class"] == 1]))
print(len(train[train["class"] == 0]))
'''

train , X_train , y_train = scale_dataset(train , oversample= True)
valid , X_valid , y_valid = scale_dataset(valid , oversample= True)
test , X_test , y_test = scale_dataset(test , oversample= True)

# %%
#len(y_train)

# %%
#sum(y_train == 0)

# %%
#sum(y_train == 1)

# %%
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
knn_model = KNeighborsClassifier(n_neighbors = 1)
knn_model.fit(X_train , y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
y_pred = knn_model.predict(X_test)

# %%
#y_pred

# %%
#y_test

# %%
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.66      0.74      2455
#            1       0.72      0.89      0.80      2455
#
#     accuracy                           0.77      4910
#    macro avg       0.79      0.77      0.77      4910
# weighted avg       0.79      0.77      0.77      4910

# %%
knn_model = KNeighborsClassifier(n_neighbors = 3)
knn_model.fit(X_train , y_train)
y_pred = knn_model.predict(X_test)
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.72      0.77      2455
#            1       0.75      0.85      0.80      2455
#
#     accuracy                           0.78      4910
#    macro avg       0.79      0.78      0.78      4910
# weighted avg       0.79      0.78      0.78      4910

# %%
knn_model = KNeighborsClassifier(n_neighbors = 5)
knn_model.fit(X_train , y_train)
y_pred = knn_model.predict(X_test)
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.74      0.78      2455
#            1       0.76      0.85      0.81      2455
#
#     accuracy                           0.80      4910
#    macro avg       0.80      0.80      0.79      4910
# weighted avg       0.80      0.80      0.79      4910

# %%
# NAIVE BAYES

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb_model = GaussianNB()
nb_model = nb_model.fit(X_train , y_train)

# %%
y_pred = nb_model.predict(X_test)
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.41      0.55      2455
#            1       0.60      0.90      0.72      2455
#
#     accuracy                           0.66      4910
#    macro avg       0.70      0.66      0.63      4910
# weighted avg       0.70      0.66      0.63      4910

# %%
# LOGISITIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr_model = LogisticRegression()
lr_model = lr_model.fit(X_train, y_train)

# %%
y_pred = lr_model.predict(X_test)
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.72      0.76      2455
#            1       0.75      0.83      0.79      2455
#
#     accuracy                           0.77      4910
#    macro avg       0.78      0.77      0.77      4910
# weighted avg       0.78      0.77      0.77      4910

# %%
# this is a test
